# %%
## data
hits = [
      {
        "_index" : "australian-financial-institutions",
        "_type" : "_doc",
        "_id" : "pxi63W4BPY5OTIm3Ya5n",
        "_score" : 1.0,
        "_source" : {
          "institutionShortName" : "ADC",
          "institutionName" : "Australian Military Bank Limited",
          "instutionCode" : "642"
        }
      },
      {
        "_index" : "australian-financial-institutions",
        "_type" : "_doc",
        "_id" : "qBi63W4BPY5OTIm3Ya5n",
        "_score" : 1.0,
        "_source" : {
          "institutionShortName" : "AMP",
          "institutionName" : "AMP Bank Limited",
          "instutionCode" : "939"
        }
      },
      {
        "_index" : "australian-financial-institutions",
        "_type" : "_doc",
        "_id" : "qRi63W4BPY5OTIm3Ya5n",
        "_score" : 1.0,
        "_source" : {
          "institutionShortName" : "ARA",
          "institutionName" : "Arab Bank Australia Limited",
          "instutionCode" : "917"
        }
      },
      {
        "_index" : "australian-financial-institutions",
        "_type" : "_doc",
        "_id" : "qhi63W4BPY5OTIm3Ya5n",
        "_score" : 1.0,
        "_source" : {
          "institutionShortName" : "ANZ",
          "institutionName" : "Australia & New Zealand Banking Group Limited",
          "instutionCode" : "1"
        }
      },
      {
        "_index" : "australian-financial-institutions",
        "_type" : "_doc",
        "_id" : "qxi63W4BPY5OTIm3Ya5n",
        "_score" : 1.0,
        "_source" : {
          "institutionShortName" : "ANZ",
          "institutionName" : "T&C Town & Country Bank (a division of Australia & New Zealand Banking Group Limited)",
          "instutionCode" : "15"
        }
      },
      {
        "_index" : "australian-financial-institutions",
        "_type" : "_doc",
        "_id" : "rBi63W4BPY5OTIm3Ya5n",
        "_score" : 1.0,
        "_source" : {
          "institutionShortName" : "APO",
          "institutionName" : "Australia Post (Money Orders)",
          "instutionCode" : "90"
        }
      },
      {
        "_index" : "australian-financial-institutions",
        "_type" : "_doc",
        "_id" : "rRi63W4BPY5OTIm3Ya5n",
        "_score" : 1.0,
        "_source" : {
          "institutionShortName" : "ASL",
          "institutionName" : "Australian Settlements Limited",
          "instutionCode" : "57"
        }
      },
      {
        "_index" : "australian-financial-institutions",
        "_type" : "_doc",
        "_id" : "rhi63W4BPY5OTIm3Ya5n",
        "_score" : 1.0,
        "_source" : {
          "institutionShortName" : "BAY",
          "institutionName" : "Auswide Bank Ltd",
          "instutionCode" : "656"
        }
      },
      {
        "_index" : "australian-financial-institutions",
        "_type" : "_doc",
        "_id" : "rxi63W4BPY5OTIm3Ya5n",
        "_score" : 1.0,
        "_source" : {
          "institutionShortName" : "BCC",
          "institutionName" : "Bananacoast Community Credit Union Limited",
          "instutionCode" : "533"
        }
      },
      {
        "_index" : "australian-financial-institutions",
        "_type" : "_doc",
        "_id" : "sBi63W4BPY5OTIm3Ya5n",
        "_score" : 1.0,
        "_source" : {
          "institutionShortName" : "BAE",
          "institutionName" : "B&E Ltd trading as Bank of Us",
          "instutionCode" : "632"
        }
      }
    ]

# %%
import urllib
from bs4 import BeautifulSoup
import requests
import webbrowser

text = 'cba'
text = urllib.parse.quote_plus(text)

url = 'https://google.com/search?q=' + text

response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

for g in soup.find_all(class_='g'):
    print(g.text)
    print('-----')

print(response.text)
# Out:
# ...';var i=['dimg_37'];_setImagesSrc(i,s);})();</script><script nonce="TwFYWUM9LdDDDqpm/hctsg==">(function(){var s='data:image/png;base64,...\x3d';var i=['dimg_39'];_setImagesSrc(i,s);})();</script><script nonce="TwFYWUM9LdDDDqpm/hctsg==">(function(){var s='data:image/png;base64,...\x3d\x3d';var i=['dimg_41'];_setImagesSrc(i,s);})();</script><script nonce="TwFYWUM9LdDDDqpm/hctsg==">(function(){var s='data:image/png;base64,...\x3d\x3d';var i=['dimg_43'];_setImagesSrc(i,s);})();</script><script nonce="TwFYWUM9LdDDDqpm/hctsg==">(function(){var s='data:image/png;base64,...\x3d';var i=['dimg_45'];_setImagesSrc(i,s);})();</script><script nonce="TwFYWUM9LdDDDqpm/hctsg==">(function(){var e='vQIqXv7SI8iCyAPUtpSABQ';(function(){
# var a=e,b=window.performance&&window.performance.navigation;b&&2==b.type&&window.ping("/gen_204?ct=backbutton&ei="+a);}).call(this);})();(function(){
# ...

# %%
#!pip install selenium 	
# Imports, of course
from     datetime   import date, datetime
import json
import time
import pytz
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import hashlib
from elasticsearch import helpers
from elasticsearch.client import Elasticsearch
from     datetime   import date, datetime
import requests
from bs4 import BeautifulSoup
